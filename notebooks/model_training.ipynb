# %%
import os
import sys
import pandas as pd
sys.path.append(os.path.abspath(".."))

from src.preprocessing import preprocess

# %%
csv_filename = '../data/results.csv'
df = pd.read_csv(csv_filename)
df.tail()
# Out:
#              date    home_team    away_team  home_score  away_score  \
# 49500  2026-07-07  Switzerland     Colombia         0.0         0.0
# 49501  2026-07-09       France      Morocco         NaN         NaN
# 49502  2026-07-10        Spain      Belgium         NaN         NaN
# 49503  2026-07-11       Norway      England         NaN         NaN
# 49504  2026-07-11    Argentina  Switzerland         NaN         NaN
#
#            tournament           city        country  neutral
# 49500  FIFA World Cup      Vancouver         Canada     True
# 49501  FIFA World Cup     Foxborough  United States     True
# 49502  FIFA World Cup      Inglewood  United States     True
# 49503  FIFA World Cup  Miami Gardens  United States     True
# 49504  FIFA World Cup    Kansas City  United States     True

# %%
df = preprocess(df)
df.head()
# Out:
#             date           home_team    away_team  home_score  away_score  \
# 34912 2011-07-07             Bolivia   Costa Rica         0.0         2.0
# 34913 2011-07-07     Solomon Islands      Vanuatu         2.0         1.0
# 34914 2011-07-08               Aruba  Saint Lucia         4.0         2.0
# 34915 2011-07-08  Dominican Republic     Anguilla         2.0         0.0
# 34916 2011-07-08              Jordan        Yemen         4.0         0.0
#
#                          tournament                   city  \
# 34912                  Copa América  San Salvador de Jujuy
# 34913                      Friendly                Honiara
# 34914  FIFA World Cup qualification             Oranjestad
# 34915  FIFA World Cup qualification          San Cristóbal
# 34916                      Friendly               Istanbul
#
#                   country  neutral   tournament_type  ...  h2h_win_pct  \
# 34912           Argentina     True  Major Tournament  ...         0.00
# 34913     Solomon Islands    False          Friendly  ...         0.75
# 34914               Aruba    False     Qualification  ...         0.50
# 34915  Dominican Republic    False     Qualification  ...         0.75
# 34916              Turkey     True          Friendly  ...         0.50
#
#          elo_diff  home_average_goals_scored  home_average_conceded_goals  \
# 34912  -97.388220                        0.4                          1.6
# 34913   83.709401                        2.7                          1.8
# 34914 -195.192814                        0.7                          3.2
# 34915  245.946371                        2.6                          2.3
# 34916  201.007469                        1.1                          1.3
#
#        home_elo_momentum  away_average_goals_scored  \
# 34912           3.747245                        1.4
# 34913         -42.791778                        0.9
# 34914         -74.315858                        0.7
# 34915           7.631400                        0.8
# 34916          23.923712                        1.5
#
#        away_average_conceded_goals  away_elo_momentum  conceded_goals_diff  \
# 34912                          1.4          -7.054369                  0.2
# 34913                          1.7         -34.665911                  0.1
# 34914                          3.1         -78.342165                  0.1
# 34915                          3.9         -44.117822                 -1.6
# 34916                          2.0           9.046563                 -0.7
#
#        scored_goals_diff
# 34912               -1.0
# 34913                1.8
# 34914                0.0
# 34915                1.8
# 34916               -0.4
#
# [5 rows x 22 columns]
