# %%
import os
import sys
import pandas as pd

# %%
csv_filename = '../data/results.csv'
df = pd.read_csv(csv_filename)
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
def categorize_tournament(tournament_name):
    name = str(tournament_name).lower()

    if 'world cup' in name or 'copa américa' in name or 'euro' in name or 'nations cup' in name:
        if 'qualification' not in name and 'qualifying' not in name and 'qualifier' not in name:
            return 'Major Tournament'
    if 'qualification' in name or 'qualifying' in name or 'qor' in name or 'qualifier' in name:
        return 'Qualification'
    if 'friendly' in name:
        return 'Friendly'
    return 'Other / Regional Cup'
df = df[:-20]
df['tournament_type'] = df['tournament'].apply(categorize_tournament)

# %%
sys.path.append(os.path.abspath('..'))
from src.elo_system import calculate_elo_ratings

# %%
df = calculate_elo_ratings(df)
df.tail()
# Out:
#              date      home_team    away_team  home_score  away_score  \
# 49460  2026-06-25        Ecuador      Germany         2.0         1.0
# 49461  2026-06-25  United States       Turkey         2.0         3.0
# 49462  2026-06-25        Curaçao  Ivory Coast         0.0         2.0
# 49463  2026-06-25       Paraguay    Australia         0.0         0.0
# 49464  2026-06-25          Japan       Sweden         1.0         1.0
#
#            tournament             city        country  neutral  \
# 49460  FIFA World Cup  East Rutherford  United States     True
# 49461  FIFA World Cup        Inglewood  United States    False
# 49462  FIFA World Cup     Philadelphia  United States     True
# 49463  FIFA World Cup      Santa Clara  United States     True
# 49464  FIFA World Cup        Arlington  United States     True
#
#         tournament_type     home_elo     away_elo
# 49460  Major Tournament  1932.251342  2007.891309
# 49461  Major Tournament  1914.562107  1855.907135
# 49462  Major Tournament  1630.640958  1802.307624
# 49463  Major Tournament  1884.877335  1925.904409
# 49464  Major Tournament  2006.019511  1762.580749

# %% [markdown]
# Just testing if elo system works.
